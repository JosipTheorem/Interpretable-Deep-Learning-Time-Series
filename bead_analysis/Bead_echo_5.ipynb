# %%
import random
import time
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

from copy import deepcopy
from typing import Dict, List, Tuple

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.ticker as ticker

from pathlib import Path

# Load DCIts
import sys
import os
sys.path.append('..')
from src.dcits import DCITS

# Load utils
from src.utils import *

# Check if CUDA is available
if torch.cuda.is_available():
    # Specify the device (index starts from 0, so cuda:0 is the first GPU)
    device = torch.device("cuda:0")
    print(f"Using {torch.cuda.get_device_name(device)}")
else:
    print("CUDA is not available. Using CPU instead.")
    device = torch.device("cpu")
    
    
from scipy.io import loadmat
from pathlib import Path
import glob, os
import numpy as np
# Out:
# Using NVIDIA GeForce RTX 5070

# %%
fov_dir = r"C:\Users\dujme\Desktop\Seminar_venv\10rad_60perc_echo5"
n= len(glob.glob(os.path.join(fov_dir, "*.mat")))
b=0
for i in range(1,n-1):
    data = loadmat(fr"C:\Users\dujme\Desktop\Seminar_venv\10rad_60perc_echo5\bead_{i}.mat")
    if len(data['bsec']) == 599:
        b=b+1
    print(i,len(data['bsec']))
print('broj koji ima 599 podataka:', b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 fov_dir = r"C:\Users\dujme\Desktop\Seminar_venv\10rad_60perc_echo5"
# ----> 2 n= len(glob.glob(os.path.join(fov_dir, "*.mat")))
#       3 b=0
#       4 for i in range(1,n-1):
#
# NameError: name 'glob' is not defined

# %%
ECHO_DIR = Path(r"C:\Users\dujme\Desktop\Seminar_venv\10rad_60perc_echo5")
MIN_BLOCK_LENGTH = 80
N_SERIES_TO_MODEL = 8
WINDOW_CANDIDATES = [3, 5, 8, 12]
Window_lenght = 10
ORDER = [1, 1]
TEMPERATURE = 1.0
